# %% [markdown]
# <a href="https://colab.research.google.com/github/prakash1990s/prakashgit/blob/main/churn_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **# importing churn.xlsx file**

# %%
# importing churn.xlsx file
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e9284899-1e4e-4cbe-b08c-fb32a9f40dab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9284899-1e4e-4cbe-b08c-fb32a9f40dab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.ticker as mtick
import re
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('Churn (3).xlsx')
df
# Out:
#      Account length  Area code  Total day minutes  Total day calls  \
# 0               117        408              184.5               97
# 1                65        415              129.1              137
# 2               161        415              332.9               67
# 3               111        415              110.4              103
# 4                49        510              119.3              117
# ..              ...        ...                ...              ...
# 662             114        415              137.1               88
# 663             106        408               83.6              131
# 664              60        415              193.9              118
# 665             159        415              169.8              114
# 666             184        510              213.8              105
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0               31.37              351.6               80             29.89
# ...

# %%
df.head()
# Out:
#    Account length  Area code  Total day minutes  Total day calls  \
# 0             117        408              184.5               97
# 1              65        415              129.1              137
# 2             161        415              332.9               67
# 3             111        415              110.4              103
# 4              49        510              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# 1             21.95              228.5               83             19.42
# 2             56.59              317.8               97             27.01
# 3             18.77              137.3              102             11.67
# 4             20.28              215.1              109             18.28
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                215.8                 90                9.71
# ...

# %%
df.tail(10)
# Out:
#      Account length  Area code  Total day minutes  Total day calls  \
# 657              48        415              141.1              109
# 658              57        415              158.1              117
# 659             127        510              107.9              128
# 660             114        408              203.8               85
# 661              84        415              280.0              113
# 662             114        415              137.1               88
# 663             106        408               83.6              131
# 664              60        415              193.9              118
# 665             159        415              169.8              114
# 666             184        510              213.8              105
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 657             23.99              224.7               94             19.10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Account length          667 non-null    int64
#  1   Area code               667 non-null    int64
#  2   Total day minutes       667 non-null    float64
#  3   Total day calls         667 non-null    int64
#  4   Total day charge        667 non-null    float64
#  5   Total eve minutes       667 non-null    float64
#  6   Total eve calls         667 non-null    int64
#  7   Total eve charge        667 non-null    float64
#  8   Total night minutes     667 non-null    float64
#  9   Total night calls       667 non-null    int64
#  10  Total night charge      667 non-null    float64
#  11  Total intl minutes      667 non-null    float64
#  12  Total intl calls        667 non-null    int64
#  13  Total intl charge       667 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Account length   Area code  Total day minutes  Total day calls  \
# count      667.000000  667.000000         667.000000       667.000000
# mean       102.841079  436.157421         180.948126       100.937031
# std         40.819480   41.783305          55.508628        20.396790
# min          1.000000  408.000000          25.900000        30.000000
# 25%         76.000000  408.000000         146.250000        87.500000
# 50%        102.000000  415.000000         178.300000       101.000000
# 75%        128.000000  415.000000         220.700000       115.000000
# max        232.000000  510.000000         334.300000       165.000000
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# count        667.000000         667.000000       667.000000        667.000000
# mean          30.761769         203.355322       100.476762         17.285262
# std            9.436463          49.719268        18.948262          4.226160
# ...

# %%
df.shape
# Out:
# (667, 16)

# %%
df.isnull()
# Out:
#      Account length  Area code  Total day minutes  Total day calls  \
# 0             False      False              False            False
# 1             False      False              False            False
# 2             False      False              False            False
# 3             False      False              False            False
# 4             False      False              False            False
# ..              ...        ...                ...              ...
# 662           False      False              False            False
# 663           False      False              False            False
# 664           False      False              False            False
# 665           False      False              False            False
# 666           False      False              False            False
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0               False              False            False             False
# ...

# %%
df.isnull().sum()
# Out:
# Account length            0
# Area code                 0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.corr()
# Out:
#                         Account length  Area code  Total day minutes  \
# Account length                1.000000  -0.026327           0.017833
# Area code                    -0.026327   1.000000           0.051507
# Total day minutes             0.017833   0.051507           1.000000
# Total day calls               0.035703  -0.008972          -0.032306
# Total day charge              0.017839   0.051492           1.000000
# Total eve minutes             0.027043   0.017160           0.017987
# Total eve calls               0.021237   0.017783           0.043219
# Total eve charge              0.027051   0.017182           0.017945
# Total night minutes          -0.007527  -0.016832          -0.031600
# Total night calls             0.027228   0.036421           0.052761
# Total night charge           -0.007528  -0.016818          -0.031603
# Total intl minutes            0.002362  -0.037980          -0.006725
# Total intl calls              0.031279  -0.010530           0.016597
# ...

# %%
corr = df.corr()
fig, ax = plt.subplots(figsize=(12,15))
sns.heatmap(corr,annot=True, ax=ax, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
# Get the value counts for 'Churn' column
data_temp = df['Churn'].value_counts().sort_index()

fig, ax = plt.subplots(figsize=(6, 4))

# Plotting the bar chart
ax.bar(data_temp.index, data_temp, width=0.55, color=['skyblue', 'salmon'])

# Title and axis labels
ax.set_title('Churn Distribution', loc='left', fontsize=19, fontweight='bold')
ax.set_xlabel('Churn')
ax.set_ylabel('Count')

# Annotate each bar with its count value
for i, count in enumerate(data_temp):
    ax.text(i, count + 50, str(count), ha='center', fontsize=12, fontweight='bold')

# Hide spines on top and right sides
for s in ['top', 'right']:
    ax.spines[s].set_visible(False)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# %%
sns.countplot(df['Churn'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Churn'].value_counts()
# Out:
# False    572
# True      95
# Name: Churn, dtype: int64

# %%
Churned = df[df.Churn == 'True'].shape[0]
retained = df[df.Churn == 'False'].shape[0]

# %%
Ch_per = ((Churned/(Churned+retained))*100)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-20-447eb8fe8604> in <cell line: 1>()
# ----> 1 Ch_per = ((Churned/(Churned+retained))*100)
#
# ZeroDivisionError: division by zero

# %%
Ch_per
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9292d94759b8> in <cell line: 1>()
# ----> 1 ch_per
#
# NameError: name 'ch_per' is not defined

# %%
sns.countplot(x='Customer service calls', hue='Churn',data = df)
# Out:
# <Axes: xlabel='Customer service calls', ylabel='count'>

# %%
sns.countplot(x='Total night calls', hue='Churn',data = df)
# Out:
# <Axes: xlabel='Total night calls', ylabel='count'>

# %%
sns.countplot(x='Total day calls', hue='Churn', data = df)
# Out:
# <Axes: xlabel='Total day calls', ylabel='count'>

# %%
x = df.drop('Churn',axis=1)
y= df['Churn']

# %%
y
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 662    False
# 663    False
# 664    False
# 665    False
# 666    False
# Name: Churn, Length: 667, dtype: bool

# %% [markdown]
# ## **Split Data set**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#      Account length  Area code  Total day minutes  Total day calls  \
# 234              55        510              189.0              100
# 398             100        408               70.8               94
# 278              66        408               87.6               76
# 61              121        408              170.4              108
# 145             176        415              223.2               76
# ..              ...        ...                ...              ...
# 71               54        510              210.5              102
# 106             150        415              209.9               77
# 270              90        415               76.1              121
# 435             104        510               97.2               88
# 102              87        510              231.3              105
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 234             32.13              118.5               99             10.07
# ...

# %%
x_test
# Out:
#      Account length  Area code  Total day minutes  Total day calls  \
# 660             114        408              203.8               85
# 158             151        415              196.5               98
# 634             142        510              230.7              101
# 235             130        415              155.9               95
# 635             105        408              232.6               96
# ..              ...        ...                ...              ...
# 536             130        408              115.6              129
# 417              86        408               83.8              121
# 465              38        408              115.4               98
# 211              13        415              146.4               74
# 18               95        408              135.0               99
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 660             34.65               87.8              110              7.46
# ...

# %%
y_train
# Out:
# 234    False
# 398     True
# 278    False
# 61      True
# 145    False
#        ...
# 71     False
# 106    False
# 270    False
# 435    False
# 102    False
# Name: Churn, Length: 533, dtype: bool

# %%
y_test
# Out:
# 660    False
# 158    False
# 634    False
# 235    False
# 635    False
#        ...
# 536    False
# 417    False
# 465    False
# 211    False
# 18     False
# Name: Churn, Length: 134, dtype: bool

# %% [markdown]
# ### **Build Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#prediction
predict = lr.predict(x_test)
print(predict)
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False  True False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False  True False False False False False False False False False
#  False False False False  True False False False  True False False False
#  False False False False False False False False False False False False
#  False False False False False  True False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False]

# %%
lr.score(x_test,predict)
# Out:
# 1.0
